# %%
import geopandas as gpd
from sqlalchemy import create_engine
import numpy as np
import pyproj
import requests
import time
from geopy.geocoders import Nominatim
import pycatastro

# %% [markdown]
# ### Carregar fitxers SHP que tenim a la base de dades.

# %%
# Cargar el Shapefile 
# Han de estar els 4 fitxer junts.
engine = create_engine('postgresql://postgres:Inda!576074!@localhost:5432/catastro')
gdf_catastral = gpd.read_postgis('SELECT * FROM catastral', engine, geom_col='geometry')

# %%
gdf_catastral.count()
# Out:
# MAPA         15016
# DELEGACIO    15016
# MUNICIPIO    15016
# MASA         15016
# HOJA         15016
# TIPO         15016
# PARCELA      15016
# COORX        15016
# COORY        15016
# VIA          15016
# NUMERO       15009
# NUMERODUP      883
# NUMSYMBOL    15016
# AREA         15016
# FECHAALTA    15016
# FECHABAJA    15016
# NINTERNO     15016
# PCAT1        15016
# PCAT2        15016
# EJERCICIO    15016
# NUM_EXP      15016
# CONTROL      15016
# REFCAT       15016
# geometry     15016
# COBERTURA    15016
# LON          15016
# LAT          15016
# DIRECCION     6689
# dtype: int64

# %% [markdown]
# ### Creem un nou camp que és cobertura

# %%
# gdf_catastral['COBERTURA'] = 1;

# %%
print(gdf_catastral.dtypes)
# Out:
# MAPA            int64
# DELEGACIO       int64
# MUNICIPIO       int64
# MASA           object
# HOJA           object
# TIPO           object
# PARCELA        object
# COORX         float64
# COORY         float64
# VIA             int64
# NUMERO        float64
# NUMERODUP      object
# NUMSYMBOL       int64
# AREA            int64
# FECHAALTA       int64
# FECHABAJA       int64
# NINTERNO      float64
# PCAT1          object
# PCAT2          object
# EJERCICIO       int64
# NUM_EXP         int64
# CONTROL         int64
# REFCAT         object
# geometry     geometry
# COBERTURA       int64
# LON           float64
# LAT           float64
# DIRECCION      object
# dtype: object

# %% [markdown]
# ### Utilitzem API que implementa la llibreria de pycastro per obtenir les direccions.
# - A partir de la referencia catastral obtenim la direcció.
# - Aquesta API fa crides a la catastro de españa.

# %%
# Convertim les coordenades al format que volem.
# Configurar el transformador de coordenadas de UTM (zona 31N) a WGS84
transformer = pyproj.Transformer.from_crs("EPSG:25831", "EPSG:4326", always_xy=True)

# Convertir las coordenadas de UTM a latitud y longitud
gdf_catastral['LON'], gdf_catastral['LAT'] = transformer.transform(gdf_catastral['COORX'].values, gdf_catastral['COORY'].values)

# Mostrar los resultados
print(gdf_catastral.head())
# Out:
#     MAPA  DELEGACIO  MUNICIPIO   MASA     HOJA TIPO PARCELA      COORX  \
# 0  17411         17         16  16238  DG8612S    U      07  481596.82
# 1  17411         17         16  16238  DG8612S    U      05  481598.59
# 2  17411         17         16  16238  DG8612S    U      04  481583.52
# 3  17411         17         16  13344  DG8613S    U      05  481191.31
# 4  17411         17         16  13344  DG8613S    U      04  481219.76
#
#         COORY  VIA  ...    PCAT2 EJERCICIO  NUM_EXP  CONTROL          REFCAT  \
# 0  4662089.22  107  ...  DG8612S         0        0        0  1623807DG8612S
# 1  4662109.55  122  ...  DG8612S         0        0        0  1623805DG8612S
# 2  4662117.95  122  ...  DG8612S         0        0        0  1623804DG8612S
# 3  4663201.53  274  ...  DG8613S         0        0        0  1334405DG8613S
# 4  4663231.75  274  ...  DG8613S         0        0        0  1334404DG8613S
#
#                                             geometry  COBERTURA       LON  \
# 0  POLYGON ((481593.446 4662096.999, 481595.033 4...          1  2.777401
# 1  POLYGON ((481593.446 4662096.999, 481589.983 4...          1  2.777421
# 2  POLYGON ((481589.020 4662100.405, 481583.143 4...          1  2.777239
# 3  POLYGON ((481216.561 4663217.354, 481215.661 4...          1  2.772460
# 4  POLYGON ((481224.839 4663248.036, 481225.966 4...          1  2.772803
#
#          LAT  DIRECCION
# 0  42.110682       None
# 1  42.110865       None
# 2  42.110941       None
# 3  42.120690       None
# 4  42.120963       None
#
# [5 rows x 28 columns]

# %%
# Creem diccionari municipis.
gdf_catastral['MUNICIPIO'].unique()
municipios = {
    16: "BANYOLES",
    46: "CAPMANY",
    70: "ESPOLLA",
    76: "FONTCOBERTA",
    100: "LLERS",
    106: "MASARAC",
    113: "MOLLET DE PERALADA",
    117: "MONT-RAS",
    144: "PONT DE MOLINS",
    146: "PORQUERES",
    152: "RABÓS",
    167: "SANT CLIMENT SESCEBES",
    192: "SANTA CRISTINA D'ARO",
}

# %%
i = 1
def get_address_by_refcat(row):
    refcat = row['REFCAT']
    direccion = row['DIRECCION']
    municipio = row['MUNICIPIO']  # Asegúrate de que esta es la forma correcta de usar el municipio

    #Depenent del número de municipi agafem un nom.
    municipio = municipios.get(municipio, "Municipio Desconocido")

    global i
    try:
        # Solo procesa si la dirección actual es 'Error en la solicitud'
        if direccion == 'Error en la solicitud' or direccion is None:
            # Datos ficticios de ejemplo, sustitúyelos por los reales
            provincia = "GIRONA"
            
            result = pycatastro.PyCatastro.Consulta_CPMRC(provincia, municipio, srs=25831, rc=refcat)

            # print(result)
            print(f"{i}: {result.get('consulta_coordenadas').get('coordenadas').get('coord').get('ldt')}")
            i += 1        
            return result.get('consulta_coordenadas').get('coordenadas').get('coord').get('ldt')
        else:
            # No hace nada si la dirección no es 'Error en la solicitud'
            print(direccion)
            return direccion

    except Exception as e:
        print(f"Error en la solicitud para {refcat}: {e}")
        return None  # Devuelve None también en caso de excepción

# %%
# Aplicar la función a cada fila del DataFrame
gdf_catastral['DIRECCION'] = gdf_catastral.apply(get_address_by_refcat, axis=1)
# Out:
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1623807DG8612S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1623805DG8612S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1623804DG8612S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1334405DG8613S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1334404DG8613S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0635640DG8603N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0635631DG8603N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1621604DG8612S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1621605DG8612S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1621606DG8612S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1026807DG8612N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1026805DG8612N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1026806DG8612N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1026809DG8612N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1026802DG8612N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1025507DG8612N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1025506DG8612N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0131631DG8603S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0131632DG8603S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0025606DG8602N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0933315DG8603S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0131608DG8603S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0131607DG8603S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1333607DG8613S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1333604DG8613S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0232216DG8603S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0627611DG8602N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1231724DG8613S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1231723DG8613S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0739613DG8603N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0739614DG8603N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0739615DG8603N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0739616DG8603N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0739617DG8603N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0739618DG8603N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0739619DG8603N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1124110DG8612S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1124303DG8612S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1124304DG8612S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1124305DG8612S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1124306DG8612S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1124307DG8612S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1124308DG8612S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1124309DG8612S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1124310DG8612S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1124311DG8612S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1124312DG8612S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1124313DG8612S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1124314DG8612S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1124317DG8612S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1124701DG8612S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1724605DG8612S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1724612DG8612S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 2135205DG8623N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 2135206DG8623N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 2034105DG8623S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 2034106DG8623S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 2034107DG8623S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 2034108DG8623S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 2034110DG8623S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 2034113DG8623S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 2034114DG8623S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 2034115DG8623S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0131634DG8603S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0131635DG8603S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0131636DG8603S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0131637DG8603S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0131641DG8603S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0131642DG8603S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1023430DG8612S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1023431DG8612S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1123308DG8612S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1036202DG8613N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1036203DG8613N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1036204DG8613N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1036205DG8613N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1036206DG8613N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1036207DG8613N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0732745DG8603S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1734405DG8613S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0732903DG8603S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0732906DG8603S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0732909DG8603S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0732910DG8603S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0739111DG8603N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0739601DG8603N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0739602DG8603N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0739603DG8603N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0739110DG8603N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0739604DG8603N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0739605DG8603N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0739606DG8603N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0739607DG8603N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1436834DG8613N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1535701DG8613N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1535702DG8613N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1535703DG8613N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1535704DG8613N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1535705DG8613N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1535708DG8613N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0332129DG8603S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0332130DG8603S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0332131DG8603S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0332132DG8603S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0332134DG8603S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0332135DG8603S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0630501DG8603S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0630502DG8603S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1336418DG8613N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1336419DG8613N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1336420DG8613N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1336421DG8613N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1336422DG8613N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1336416DG8613N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0126151DG8602N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0126155DG8602N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1036221DG8613N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1036222DG8613N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1036223DG8613N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1036224DG8613N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1036226DG8613N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1036228DG8613N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1036229DG8613N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1526907DG8612N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1431928DG8613S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 9927731DG7692N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 9927733DG7692N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1535709DG8613N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0630503DG8603S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0631404DG8603S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0922517DG8602S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0922510DG8602S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1431911DG8613S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1431929DG8613S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0733801DG8603S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0732925DG8603S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0733806DG8603S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0733807DG8603S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0739620DG8603N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0739621DG8603N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0739622DG8603N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0739623DG8603N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0739624DG8603N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0739625DG8603N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0739626DG8603N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0739627DG8603N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0726505DG8602N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0826810DG8602N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0825702DG8602N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0825703DG8602N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0825704DG8602N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0825705DG8602N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0825706DG8602N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0825701DG8602N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0825707DG8602N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0332136DG8603S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0332139DG8603S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0332140DG8603S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0332141DG8603S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0332142DG8603S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0332143DG8603S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0332144DG8603S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0332145DG8603S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0729503DG8602N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0729501DG8602N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0729502DG8602N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0832614DG8603S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0739629DG8603N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0739630DG8603N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0739631DG8603N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0739632DG8603N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0739633DG8603N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0739628DG8603N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0739634DG8603N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0739635DG8603N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0739636DG8603N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0835501DG8603N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0835502DG8603N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1124704DG8612S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1124705DG8612S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1124706DG8612S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1124707DG8612S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0734801DG8603S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0734808DG8603S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0734817DG8603S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0734818DG8603S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0826903DG8602N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 0437809DG8603N: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 2034109DG8623S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1124708DG8612S: 'NoneType' object has no attribute 'get'
# {'error': 'Peticion denegada. Ha superado el limite de peticiones por hora.'}
# Error en la solicitud para 1124709DG8612S: 'NoneType' object has no attribute 'get'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 2
#       1 # Aplicar la función a cada fila del DataFrame
# ----> 2 gdf_catastral['DIRECCION'] = gdf_catastral.apply(get_address_by_refcat, axis=1)
#
# File ~\miniconda3\envs\catastro\lib\site-packages\geopandas\geodataframe.py:1581, in GeoDataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    1579 @doc(pd.DataFrame)
#    1580 def apply(self, func, axis=0, raw=False, result_type=None, args=(), **kwargs):
# -> 1581     result = super().apply(
#    1582         func, axis=axis, raw=raw, result_type=result_type, args=args, **kwargs
#    1583     )
#    1584     # pandas <1.4 re-attach last geometry col if lost
#    1585     if (
#    1586         not compat.PANDAS_GE_14
#    1587         and isinstance(result, GeoDataFrame)
#    1588         and result._geometry_column_name is None
#    1589     ):
#
# File ~\miniconda3\envs\catastro\lib\site-packages\pandas\core\frame.py:9423, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9412 from pandas.core.apply import frame_apply
#    9414 op = frame_apply(
#    9415     self,
#    9416     func=func,
#    (...)
#    9421     kwargs=kwargs,
#    9422 )
# -> 9423 return op.apply().__finalize__(self, method="apply")
#
# File ~\miniconda3\envs\catastro\lib\site-packages\pandas\core\apply.py:678, in FrameApply.apply(self)
#     675 elif self.raw:
#     676     return self.apply_raw()
# --> 678 return self.apply_standard()
#
# File ~\miniconda3\envs\catastro\lib\site-packages\pandas\core\apply.py:798, in FrameApply.apply_standard(self)
#     797 def apply_standard(self):
# --> 798     results, res_index = self.apply_series_generator()
#     800     # wrap results
#     801     return self.wrap_results(results, res_index)
#
# File ~\miniconda3\envs\catastro\lib\site-packages\pandas\core\apply.py:814, in FrameApply.apply_series_generator(self)
#     811 with option_context("mode.chained_assignment", None):
#     812     for i, v in enumerate(series_gen):
#     813         # ignore SettingWithCopy here in case the user mutates
# --> 814         results[i] = self.f(v)
#     815         if isinstance(results[i], ABCSeries):
#     816             # If we have a view on v, we need to make a copy because
#     817             #  series_generator will swap out the underlying data
#     818             results[i] = results[i].copy(deep=False)
#
# Cell In[31], line 17, in get_address_by_refcat(row)
#      13 if direccion == 'Error en la solicitud' or direccion is None:
#      14     # Datos ficticios de ejemplo, sustitúyelos por los reales
#      15     provincia = "GIRONA"
# ---> 17     result = pycatastro.PyCatastro.Consulta_CPMRC(provincia, municipio, srs=25831, rc=refcat)
#      19     print(result)
#      20     print(f"{i}: {result.get('consulta_coordenadas').get('coordenadas').get('coord').get('ldt')}")
#
# File ~\miniconda3\envs\catastro\lib\site-packages\pycatastro\__init__.py:515, in PyCatastro.Consulta_CPMRC(cls, provicia, municipio, srs, rc)
#     509 params = {'SRS': srs,
#     510           'Provincia': provicia,
#     511           'Municipio': municipio,
#     512           'RC': rc}
#     514 url = cls.base_url + "/OVCCoordenadas.asmx/Consulta_CPMRC"
# --> 515 response = requests.get(url, params=params)
#     516 return xmltodict.parse(response.content, process_namespaces=False, xml_attribs=False)
#
# File ~\miniconda3\envs\catastro\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\miniconda3\envs\catastro\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\miniconda3\envs\catastro\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\miniconda3\envs\catastro\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\miniconda3\envs\catastro\lib\site-packages\requests\adapters.py:589, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     586     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     588 try:
# --> 589     resp = conn.urlopen(
#     590         method=request.method,
#     591         url=url,
#     592         body=request.body,
#     593         headers=request.headers,
#     594         redirect=False,
#     595         assert_same_host=False,
#     596         preload_content=False,
#     597         decode_content=False,
#     598         retries=self.max_retries,
#     599         timeout=timeout,
#     600         chunked=chunked,
#     601     )
#     603 except (ProtocolError, OSError) as err:
#     604     raise ConnectionError(err, request=request)
#
# File ~\miniconda3\envs\catastro\lib\site-packages\urllib3\connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 response_conn = conn if not release_conn else None
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#     809 clean_exit = True
#
# File ~\miniconda3\envs\catastro\lib\site-packages\urllib3\connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~\miniconda3\envs\catastro\lib\site-packages\urllib3\connection.py:466, in HTTPConnection.getresponse(self)
#     463 from .response import HTTPResponse
#     465 # Get the response from http.client.HTTPConnection
# --> 466 httplib_response = super().getresponse()
#     468 try:
#     469     assert_header_parsing(httplib_response.msg)
#
# File ~\miniconda3\envs\catastro\lib\http\client.py:1348, in HTTPConnection.getresponse(self)
#    1346 try:
#    1347     try:
# -> 1348         response.begin()
#    1349     except ConnectionError:
#    1350         self.close()
#
# File ~\miniconda3\envs\catastro\lib\http\client.py:316, in HTTPResponse.begin(self)
#     314 # read until we get a non-100 response
#     315 while True:
# --> 316     version, status, reason = self._read_status()
#     317     if status != CONTINUE:
#     318         break
#
# File ~\miniconda3\envs\catastro\lib\http\client.py:277, in HTTPResponse._read_status(self)
#     276 def _read_status(self):
# --> 277     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278     if len(line) > _MAXLINE:
#     279         raise LineTooLong("status line")
#
# File ~\miniconda3\envs\catastro\lib\socket.py:669, in SocketIO.readinto(self, b)
#     667 while True:
#     668     try:
# --> 669         return self._sock.recv_into(b)
#     670     except timeout:
#     671         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
gdf_catastral
# Out:
#         MAPA  DELEGACIO  MUNICIPIO   MASA     HOJA TIPO PARCELA      COORX  \
# 0      17411         17         16  16238  DG8612S    U      07  481596.82
# 1      17411         17         16  16238  DG8612S    U      05  481598.59
# 2      17411         17         16  16238  DG8612S    U      04  481583.52
# 3      17411         17         16  13344  DG8613S    U      05  481191.31
# 4      17411         17         16  13344  DG8613S    U      04  481219.76
# ...      ...        ...        ...    ...      ...  ...     ...        ...
# 15011  17444         17        192  99199  DG9391N    U      07  499936.40
# 15012  17444         17        192  99951  DG9299N    U      02  499840.31
# 15013  17444         17        192  99951  DG9299N    U      01  499844.64
# 15014  17444         17        192  97479  DG9394N    U      03  499652.42
# 15015  17444         17        192  97479  DG9394N    U      02  499670.18
#
#             COORY  VIA  ...    PCAT2 EJERCICIO  NUM_EXP  CONTROL  \
# 0      4662089.22  107  ...  DG8612S         0        0        0
# 1      4662109.55  122  ...  DG8612S         0        0        0
# 2      4662117.95  122  ...  DG8612S         0        0        0
# 3      4663201.53  274  ...  DG8613S         0        0        0
# 4      4663231.75  274  ...  DG8613S         0        0        0
# ...           ...  ...  ...      ...       ...      ...      ...
# 15011  4631780.85  339  ...  DG9391N         0        0        0
# 15012  4629301.74  384  ...  DG9299N         0        0        0
# 15013  4629322.03  385  ...  DG9299N         0        0        0
# 15014  4634524.11   87  ...  DG9394N         0        0        0
# 15015  4634547.67   87  ...  DG9394N         0        0        0
#
#                REFCAT                                           geometry  \
# 0      1623807DG8612S  POLYGON ((481593.446 4662096.999, 481595.033 4...
# 1      1623805DG8612S  POLYGON ((481593.446 4662096.999, 481589.983 4...
# 2      1623804DG8612S  POLYGON ((481589.020 4662100.405, 481583.143 4...
# 3      1334405DG8613S  POLYGON ((481216.561 4663217.354, 481215.661 4...
# 4      1334404DG8613S  POLYGON ((481224.839 4663248.036, 481225.966 4...
# ...               ...                                                ...
# 15011  9919907DG9391N  POLYGON ((499923.992 4631795.232, 499940.606 4...
# 15012  9995102DG9299N  POLYGON ((499844.257 4629303.927, 499843.969 4...
# 15013  9995101DG9299N  POLYGON ((499844.257 4629303.927, 499819.618 4...
# 15014  9747903DG9394N  POLYGON ((499671.574 4634513.210, 499668.942 4...
# 15015  9747902DG9394N  POLYGON ((499683.317 4634533.565, 499680.749 4...
#
#        COBERTURA       LON        LAT  DIRECCION
# 0              1  2.777401  42.110682       None
# 1              1  2.777421  42.110865       None
# 2              1  2.777239  42.110941       None
# 3              1  2.772460  42.120690       None
# 4              1  2.772803  42.120963       None
# ...          ...       ...        ...        ...
# 15011          1  2.999234  41.837919       None
# 15012          1  2.998077  41.815590       None
# 15013          1  2.998129  41.815773       None
# 15014          1  2.995812  41.862628       None
# 15015          1  2.996026  41.862840       None
#
# [15016 rows x 28 columns]

# %% [markdown]
# ### Fem la connexió a la BD i penjem el df

# %%
# Conexión a la base de datos PostgreSQL/PostGIS
engine = create_engine('postgresql://postgres:Inda!576074!@localhost:5432/catastro')

# Guardem les dades a Postrgres
gdf_catastral.to_postgis('catastral', engine, if_exists='replace')
